# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import imutils
import easyocr
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img = cv2.imread('image2.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray,11,17,17)
edged = cv2.Canny(bfilter,30,200)
plt.imshow(cv2.cvtColor(edged,cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8688a9452dd1> in <module>
#       1 bfilter = cv2.bilateralFilter(gray,11,17,17)
#       2 edged = cv2.Canny(bfilter,30,200)
# ----> 3 plt.imshow(cv2.cvtColor(edged,cv2.COLOR_BGR2RBG))
#
# AttributeError: module 'cv2.cv2' has no attribute 'COLOR_BGR2RBG'
